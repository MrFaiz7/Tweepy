# %%
import tweepy
import pandas as pd

# %%
# Variables that contains the credentials to access Twitter API
consumer_key = "your consumer key"
consumer_secret_key = "your consumer secret key"

access_token = "your access token"
access_token_secret = "your access token secret"

# %%
# authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret_key)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ## Getting tweets by user

# %%
user = 'Cristiano'
limit=300

#tweets = api.user_timeline(screen_name=user, count=limit, tweet_mode='extended')


#Twitter Evaluate account gives only 200 tweets per request to get more we'll call tweepy.Cursor
tweets = tweepy.Cursor(api.user_timeline, screen_name=user, count=200, tweet_mode='extended').items(limit)

# create DataFrame
columns = ['User', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text])

df = pd.DataFrame(data, columns=columns)

print(df)
# Out:
#           User                                              Tweet
# 0    Cristiano            Keep working 💪🏽 https://t.co/a9juDBFehE
# 1    Cristiano  Getting ready for the return of the biggest cl...
# 2    Cristiano  Very important Premier League win before we ch...
# 3    Cristiano  Back on track! Nobody gives up and there’s onl...
# 4    Cristiano         Focus 🔴⚫️ 🙏🏽 #mufc https://t.co/XEgTuREPKO
# ..         ...                                                ...
# 295  Cristiano  Gran Carattere, bravi ragazzi!!👏🏽💪🏽\n#finoalla...
# 296  Cristiano  Focused on my recovery to come back soon!⚽💪🏽 h...
# 297  Cristiano      Love this feeling ⚽⚽⚽ https://t.co/e7bZ9vtJJU
# 298  Cristiano  Boa vitória equipa! 💪🇵🇹\nEstamos a um passo do...
# 299  Cristiano  Feliz aniversário meu amor❤️❤️❤️❤️❤️ https://t...
#
# [300 rows x 2 columns]

# %% [markdown]
# ## Searching tweets by hashtags

# %%
keywords = ['ManchesterUnited','UefaChampionsleague']
limit=200


##Twitter Evaluate account gives only 100 tweets per request for query hashtags to get more we'll call tweepy.Cursor
tweets = tweepy.Cursor(api.search_tweets, q=keywords, count=100, tweet_mode='extended').items(limit)

# create DataFrame
columns = ['User', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text])

df = pd.DataFrame(data, columns=columns)

print(df)
# Out:
#                User                                              Tweet
# 0       ManUtdFanKe  RT @FixedGamesBoss: #carabaocup #premierleague...
# 1    FixedGamesBoss  #carabaocup #premierleague #facup #football #c...
# 2       mufcfanbabe  RT @ajhopenow: @martialxtra_ #MUFC  would be w...
# 3         ajhopenow  @martialxtra_ #MUFC  would be way different in...
# 4            prahz_  Smoke a pack of cigarette everyday but at the ...
# ..              ...                                                ...
# 195       TGoalpost  Atletico Madrid will host Manchester United in...
# 196   goalooin_live  ⚽️UEFA Champions League\n\n💡Pick:\n1️⃣ #Atleti...
# 197      ope_ibukun  https://t.co/LLt5sxyKb4\n\n#football #EPL #pau...
# 198  footballhomevn  Man Utd Could Lineup (4-3-3) or (4-2-2-2) vs A...
# 199           ftwgm  RT @PorosHalangID: Match day!👋🔴\n\n#UCL : Atle...
#
# [200 rows x 2 columns]

# %%
keywords = ['racism', 'blacklivesmatter' ,'say no to racism']
limit=200


##Twitter Evaluate account gives only 100 tweets per request for query hashtags to get more we'll call tweepy.Cursor
tweets = tweepy.Cursor(api.search_tweets, q=keywords, count=100, tweet_mode='extended').items(limit)

# create DataFrame
columns = ['User', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text])

df = pd.DataFrame(data, columns=columns)

print(df)
# Out:
#                User                                              Tweet
# 0           ubupaci  RT @GeneralDon5: USA is like a plague . They h...
# 1          j_chaka_  RT @GeneralDon5: USA is like a plague . They h...
# 2        TeekayObus  RT @GeneralDon5: USA is like a plague . They h...
# 3          Mustyh81  RT @GeneralDon5: USA is like a plague . They h...
# 4     Vijay04358571  RT @GeneralDon5: USA is like a plague . They h...
# ..              ...                                                ...
# 195       EAGLOVER_  RT @GeneralDon5: USA is like a plague . They h...
# 196   yawar62283800  RT @GeneralDon5: USA is like a plague . They h...
# 197       LgbtqEric  RT @GeneralDon5: USA is like a plague . They h...
# 198  Leahs_Daughter  RT @GeneralDon5: USA is like a plague . They h...
# 199     mathekaseba  RT @GeneralDon5: USA is like a plague . They h...
#
# [200 rows x 2 columns]

# %%
keywords = ['apple', 'tesla' ,'NASA']
limit=200


##Twitter Evaluate account gives only 100 tweets per request for query hashtags to get more we'll call tweepy.Cursor
tweets = tweepy.Cursor(api.search_tweets, q=keywords, count=100, tweet_mode='extended').items(limit)

# create DataFrame
columns = ['User', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text])

df = pd.DataFrame(data, columns=columns)

print(df)
# Out:
#               User                                              Tweet
# 0         R_Sa2022  @dogecoin @Ukraine @olex_scherba @TomicahTD @D...
# 1       nwakalordd  @SaglaMahmut61 @HaberReport öyle deme hocam bu...
# 2  Michael30351989  I will set up high quality shopify store, shop...
# 3  Sathyavathi_S01  @amazon @Apple @Google @Tesla @SpaceX @BlueOri...
# 4         DCBronco  @BodhisattvaPGH @ASewcialist his money into hi...
# 5       TSPORTPAGE  @MIT @NASA @IBM @Microsoft @Dell @Apple @Qualc...
# 6       TSPORTPAGE  @MIT @NASA @IBM @Microsoft @Dell @Apple @Qualc...
# 7       TSPORTPAGE  @MIT @NASA Inventor ✨ Saint: Super Computer Lo...
# 8   Brainmosquito1  @adilzaman2 @tejuu26 We are also working at go...
# 9        JuggaloPc  @KingTut2120 What medical condition is this lo...

# %%
keywords = ['python']
limit=200


##Twitter Evaluate account gives only 100 tweets per request for query hashtags to get more we'll call tweepy.Cursor
tweets = tweepy.Cursor(api.search_tweets, q=keywords, count=100, tweet_mode='extended').items(limit)

# create DataFrame
columns = ['User', 'Tweet']
data = []

for tweet in tweets:
    data.append([tweet.user.screen_name, tweet.full_text])

df = pd.DataFrame(data, columns=columns)

print(df)
# Out:
#                 User                                              Tweet
# 0        IndieAngles  RT @RedFox_App: Stay One Step Ahead of Cybercr...
# 1         PushTwitch  RT @RedFox_App: Stay One Step Ahead of Cybercr...
# 2            SSXman2  RT @Sheraj99: Best of Vim Command Cheat Sheet ...
# 3        SvartRavn89  RT @Seb_Lach: Monty Python:) tyle miesiecy rob...
# 4      pihole_fosser  I am a #RaspberryPi #Python scripted bot\nThis...
# ..               ...                                                ...
# 195     aidanskinner  @nickmward in Python this is "from datetime im...
# 196   finance_python  Kur aynı kalsa 13,8 alsak ve hadi ekonomi de %...
# 197  NavaneethhGopal  RT @Jeande_d: A free online book that covers a...
# 198        Bills_Bot  RT @VeilleCyber3: ‘Simple’ #AI Can Anticipate ...
# 199          SSXman2  RT @everythingCour1: Python Data Science And M...
#
# [200 rows x 2 columns]
